# %% [markdown]
# # DataFrame In Pandas

# %%
import pandas as pd

# %%
data = {"Name":["Utam","Rajdeep","Adarsh"],
        "Age":[21,22,20],
        "Mark":[85,90,78]
       }

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       Name  Age  Mark
# 0     Utam   21    85
# 1  Rajdeep   22    90
# 2   Adarsh   20    78

# %%
df.head()
# Out:
#       Name  Age  Mark
# 0     Utam   21    85
# 1  Rajdeep   22    90
# 2   Adarsh   20    78

# %%
df.head(2)
# Out:
#       Name  Age  Mark
# 0     Utam   21    85
# 1  Rajdeep   22    90

# %%
df.tail()
# Out:
#       Name  Age  Mark
# 0     Utam   21    85
# 1  Rajdeep   22    90
# 2   Adarsh   20    78

# %%
df.tail(2)
# Out:
#       Name  Age  Mark
# 1  Rajdeep   22    90
# 2   Adarsh   20    78

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Mark'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Mark    3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#         Age       Mark
# count   3.0   3.000000
# mean   21.0  84.333333
# std     1.0   6.027714
# min    20.0  78.000000
# 25%    20.5  81.500000
# 50%    21.0  85.000000
# 75%    21.5  87.500000
# max    22.0  90.000000

# %%
df["Age"]
# Out:
# 0    21
# 1    22
# 2    20
# Name: Age, dtype: int64

# %%
df[["Name", "Mark"]]
# Out:
#       Name  Mark
# 0     Utam    85
# 1  Rajdeep    90
# 2   Adarsh    78

# %%
df.loc[0]
# Out:
# Name    Utam
# Age       21
# Mark      85
# Name: 0, dtype: object

# %%
df.loc[2]
# Out:
# Name    Adarsh
# Age         20
# Mark        78
# Name: 2, dtype: object

# %%
df.iloc[0]
# Out:
# Name    Utam
# Age       21
# Mark      85
# Name: 0, dtype: object

# %%
df.iloc[2]
# Out:
# Name    Adarsh
# Age         20
# Mark        78
# Name: 2, dtype: object

# %%
df[df["Mark"] > 80]
# Out:
#       Name  Age  Mark
# 0     Utam   21    85
# 1  Rajdeep   22    90

# %%
df[(df["Mark"] > 80) & (df["Age"] > 21)]
# Out:
#       Name  Age  Mark
# 1  Rajdeep   22    90

# %%
df["Result"] = ["Pass","Pass","Pass"]

# %%
df.loc[0, "Mark"] = 80

# %%
df.sort_values("Mark")
# Out:
#       Name  Age  Mark Result
# 2   Adarsh   20    78   Pass
# 0     Utam   21    80   Pass
# 1  Rajdeep   22    90   Pass

# %%
df.sort_values("Age")
# Out:
#       Name  Age  Mark Result
# 2   Adarsh   20    78   Pass
# 0     Utam   21    80   Pass
# 1  Rajdeep   22    90   Pass

# %%
df.sort_values("Mark", ascending=False)
# Out:
#       Name  Age  Mark Result
# 1  Rajdeep   22    90   Pass
# 0     Utam   21    80   Pass
# 2   Adarsh   20    78   Pass

# %%
df.sort_index()
# Out:
#       Name  Age  Mark Result
# 0     Utam   21    80   Pass
# 1  Rajdeep   22    90   Pass
# 2   Adarsh   20    78   Pass

# %%
df.isnull()
# Out:
#     Name    Age   Mark  Result
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False  False   False

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Mark      0
# Result    0
# dtype: int64

# %%
df.dropna()
# Out:
#       Name  Age  Mark Result
# 0     Utam   21    80   Pass
# 1  Rajdeep   22    90   Pass
# 2   Adarsh   20    78   Pass

# %%
df.fillna(0)
# Out:
#       Name  Age  Mark Result
# 0     Utam   21    80   Pass
# 1  Rajdeep   22    90   Pass
# 2   Adarsh   20    78   Pass

# %%
df.groupby("Name")["Mark"].mean()
# Out:
# Name
# Adarsh     78.0
# Rajdeep    90.0
# Utam       80.0
# Name: Mark, dtype: float64

# %%
df["Mark"].apply(lambda x: x + 5)
# Out:
# 0    85
# 1    95
# 2    83
# Name: Mark, dtype: int64
