# %% [markdown]
# # 🤖 KNN (K-Nearest Neighbors) Regressor

# %% [markdown]
# ## 🔰 Import Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 🔰 Load CSV

# %%
df = pd.read_csv("knn_regression_house_price_dataset.csv")

# %%
df
# Out:
#      area_sqft  bedrooms  house_age  distance_city_km      price
# 0         1360         4         29              3.00  186418.85
# 1         1794         4         18              3.20  233288.42
# 2         1630         2         16             15.46  185510.14
# 3         1595         3         23             14.29  173915.36
# 4         2138         1         18              6.11  245415.03
# ..         ...       ...        ...               ...        ...
# 195       1995         4         13              8.72  263668.35
# 196       1636         5         19              3.21  216685.29
# 197       2353         2         18             12.55  286878.85
# 198       2020         4         25             17.51  252076.28
# 199       2989         2         14             13.28  387280.39
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    area_sqft  bedrooms  house_age  distance_city_km      price
# 0       1360         4         29              3.00  186418.85
# 1       1794         4         18              3.20  233288.42
# 2       1630         2         16             15.46  185510.14
# 3       1595         3         23             14.29  173915.36
# 4       2138         1         18              6.11  245415.03

# %% [markdown]
# ## 🔰 Features & Target

# %%
x = df.drop("price", axis=1)

# %%
y = df["price"]

# %% [markdown]
# ## 🔰 Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled = StandardScaler()
x_train = scaled.fit_transform(x_train)
x_test = scaled.transform(x_test)

# %%
df.head()
# Out:
#    area_sqft  bedrooms  house_age  distance_city_km      price
# 0       1360         4         29              3.00  186418.85
# 1       1794         4         18              3.20  233288.42
# 2       1630         2         16             15.46  185510.14
# 3       1595         3         23             14.29  173915.36
# 4       2138         1         18              6.11  245415.03

# %% [markdown]
# ## 🔰 Train Decision Tree Model

# %%
model = KNeighborsRegressor(n_neighbors = 5)

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# ## 🔰 Prediction

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([307935.756, 345922.002, 323922.298, 209176.484, 218509.994,
#        116911.42 , 200164.778, 291761.002, 307064.846, 274533.934,
#        224221.992, 116964.544, 371143.984, 385153.766, 251563.06 ,
#        240862.442, 264652.046, 339591.242, 154116.104, 179209.45 ,
#        395865.984, 222158.71 ,  88837.356, 109820.532, 323821.092,
#        381231.664, 397286.086, 387905.708, 304358.794, 270200.862,
#        179209.45 , 377367.01 , 389712.652, 198654.19 , 284743.112,
#        253124.994, 118649.706, 352740.51 , 256436.32 , 363786.346])

# %% [markdown]
# ## 🔰 Accuracy

# %%
ac = accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ac = accuracy_score(y_test, y_pred)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:359, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     357 # Compute accuracy for each possible representation
#     358 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 359 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     360 check_consistent_length(y_true, y_pred, sample_weight)
#     362 if y_type.startswith("multilabel"):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:117, in _check_targets(y_true, y_pred)
#     115 # No metrics support "multiclass-multioutput" format
#     116 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 117     raise ValueError("{0} is not supported".format(y_type))
#     119 if y_type in ["binary", "multiclass"]:
#     120     xp, _ = get_namespace(y_true, y_pred)
#
# ValueError: continuous is not supported

# %% [markdown]
# ## 🔰 r2_score

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 0.8413299973731136
